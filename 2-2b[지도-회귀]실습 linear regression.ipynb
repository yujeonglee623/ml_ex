# %% [markdown]
# # 회귀 예측 모델 실습

# %% [markdown]
# - 데이터 파일 : `auto-mpg.csv`

# %% [markdown]
# ###  컬럼 정보
# - MPG (miles per gallon - 연비)
# - cylinders (실린더 갯수)
# - engine displacement (inches 배기량)
# - horsepower (마력)
# - vehicle weight (lbs. 무게)
# - time to accelerate from O to 60 mph (sec. 60mph까지 걸리는 시간)
# - model year
# - origin of car (1. American,   2. European,   3. Japanese).
# - Also provided are the car labels (types)

# %% [markdown]
# ## [목표]
# - mpg (mile per gallern, 자동차 연비)  를 예측하는 모델을 만드세요.

# %% [markdown]
# # 라이브러리, 데이터 로딩

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# datas_ml\auto-mpg.csv
data_path = "datas_ml/auto-mpg.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     392 non-null    float64
#  1   cyl     392 non-null    int64
#  2   displ   392 non-null    float64
#  3   hp      392 non-null    int64
#  4   weight  392 non-null    int64
#  5   accel   392 non-null    float64
#  6   yr      392 non-null    int64
#  7   origin  392 non-null    int64
#  8   name    392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
df['name'].value_counts()
# Out:
# name
# amc matador        5
# toyota corolla     5
# ford pinto         5
# toyota corona      4
# amc hornet         4
#                   ..
# ford mustang gl    1
# vw pickup          1
# dodge rampage      1
# ford ranger        1
# chevy s-10         1
# Name: count, Length: 301, dtype: int64

# %%
df['name'].nunique()
# Out:
# 301

# %% [markdown]
# # X, y 데이터 분리

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'displ', 'hp', 'weight', 'accel', 'yr', 'origin', 'name'], dtype='object')

# %%
# 예측할 정답
y = df['mpg']

# %% [markdown]
# - name은 제외

# %%
# X = df.loc[:, 'cyl':'origin']
X = df.loc[:, 'cyl' : 'origin']
X.head()
# Out:
#    cyl  displ   hp  weight  accel  yr  origin
# 0    8  307.0  130    3504   12.0  70       1
# 1    8  350.0  165    3693   11.5  70       1
# 2    8  318.0  150    3436   11.0  70       1
# 3    8  304.0  150    3433   12.0  70       1
# 4    8  302.0  140    3449   10.5  70       1

# %% [markdown]
# - name을 넣을 경우

# %%
X = df.loc[:, 'cyl' : 'name']
X.head()
# Out:
#    cyl  displ   hp  weight  accel  yr  origin                       name
# 0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4    8  302.0  140    3449   10.5  70       1                ford torino

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
X.head()
# Out:
#    cyl  displ   hp  weight  accel  yr  origin                       name
# 0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4    8  302.0  140    3449   10.5  70       1                ford torino

# %%
# name 컬럼을  onehotencoing 변환하기
# remainder='passthrough' 나머지는 통과시켜라는 듯

ct = ColumnTransformer([ ('encoder', OneHotEncoder(), [7]) ], remainder='passthrough')

# %%
X = ct.fit_transform(X)

# %%
X[:5]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 40 stored elements and shape (5, 308)>

# %% [markdown]
# # 학습용, 테스트용으로 분리

# %%
from sklearn.model_selection import train_test_split

# %%
# train : test => 8:2로 분할, 재현을 위핸 random seed => 7
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %% [markdown]
# # 모델 학습

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model = LinearRegression()

# %%
# 학습하기전의 회귀선의 기울기 상태
lr_model.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # 학습하기전의 회귀선의 기울기 상태
# ----> 2 lr_model.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
# 학습 수행
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model
#         4.55766463e+00,  0.00000000e+00,  1.01750223e-01, -2.86600584e+00,
#        -3.54395058e+00,  9.61165190e-02,  1.27777747e-01, -2.33298283e+00,
#         0.00000000e+00,  1.37072184e+01,  2.19516787e+00, -3.18322127e-01,
#         0.00000000e+00, -9.91600597e-01, -5.52075669e+00, -6.13567491e+00,
#         0.00000000e+00, -5.15775047e+00, -7.67039212e+00,  6.07761756e+00,
#         0.00000000e+00,  1.43443790e+01,  3.51950125e+00,  1.42532876e+01,
#        -1.11626095e+00, -9.83658470e-01, -5.87491119e-03, -1.68360929e-02,
#        -3.77189394e-03, -4.26795737e-01,  5.63865139e-01,  1.12921048e+00])

# %%
lr_model.intercept_
# Out:
# np.float64(5.084540196094132)

# %% [markdown]
# # 검증하기

# %%
y_pred = lr_model.predict(X_test)

# %%
y_pred
# Out:
# array([27.1206431 , 25.66205592, 16.66599566, 28.42379842, 25.68314143,
#        26.33290274, 24.82090388, 25.27439803, 26.90825205, 29.33689652,
#        27.66871767, 28.99319877, 27.46714436, 15.87284041, 13.19598526,
#        20.3563785 , 26.39593516, 30.5632244 , 22.57529712, 19.3321585 ,
#        28.03728571, 32.70138618, 14.06396997, 27.6648256 , 25.21760325,
#        17.74999121, 13.09365038, 21.67601224, 14.91060321, 34.15277183,
#        36.49974526, 32.29768947, 12.22769759,  7.03538039, 27.48861625,
#        24.24129386, 27.12432797, 28.26381088, 16.30963187, 17.5975817 ,
#        30.69069423, 15.90409385, 10.06618494, 25.978699  , 25.5094795 ,
#        29.94989805, 24.85034582, 33.46171439, 28.07303837, 19.42169311,
#        29.78116327, 27.74924819, 31.36294947, 15.43319491, 13.47580009,
#        21.44498332, 16.86426006, 29.06406899, 14.95964303, 27.15683295,
#        27.72787553, 15.98990082,  9.73648233, 34.07262417, 19.28287681,
#        28.8641855 , 24.48739635, 28.25823255, 25.6546827 , 31.43684886,
#        33.52716302, 14.4263939 , 31.19680844, 29.22089036, 31.56065191,
#        15.68365919, 31.64781067, 26.04064545, 27.13141991])

# %% [markdown]
# - RMSE 계산

# %%
np.sqrt(((y_test - y_pred)**2).mean()) # RMSE
# Out:
# np.float64(3.555646423043206)

# %% [markdown]
# - R2 score

# %%
# 결정계수 계산
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.7729188665788533

# %% [markdown]
# 결정 계수 해석 : 모델이 전체 변동의 77%를 설명함

# %% [markdown]
# # 실제값과 모델예측 결과 시각화

# %%
df_test = y_test.to_frame()
df_test['y_pred'] = y_pred

# %%
df_test
# Out:
#       mpg     y_pred
# 238  30.5  27.120643
# 270  23.8  25.662056
# 213  13.0  16.665996
# 357  24.2  28.423798
# 57   25.0  25.683141
# ..    ...        ...
# 346  34.7  31.560652
# 132  16.0  15.683659
# 352  32.9  31.647811
# 177  22.0  26.040645
# 80   28.0  27.131420
#
# [79 rows x 2 columns]

# %%
# df_test 데이터 프레임 인덱스 reset하기
df_test = df_test.reset_index(drop=True)

# %%
df_test.plot()
plt.show()
